# %%
import numpy as np
from matplotlib import pyplot as plt

#configure plotting
# %matplotlib inline
# %config InlineBackend.figure_format = 'svg'
import matplotlib
matplotlib.rcParams['figure.figsize'] =  (8,5)
matplotlib.rcParams['text.usetex'] = True
matplotlib.rcParams['font.size'] = 16
matplotlib.rcParams['font.family'] = 'serif'

import sys
sys.path.append('/home/james/work/gpclust/')

# %% [markdown]
# #Mixture of Gaussians
#
# ###James Hensman, November 2014
#
# This is a very simple demo to show how to use GPclust to build a mixture of Gaussians. We'll construct some toy data, fit the model and do some very simple analyis of the posterior.
#
# First, generate a two-dimensional data set.

# %%
np.random.seed(1)
Nclust = 15
dim = 2
Nmin = 25
Nmax = 50
Ndata = np.random.randint(Nmin, Nmax, Nclust)
means = np.random.randn(Nclust, dim)*9
aa = [np.random.randn(dim, dim+1) for i in range(Nclust)]
Sigmas = [np.dot(a, a.T) for a in aa]
X = np.vstack([np.random.multivariate_normal(mu, cov, (n,)) for mu, cov, n in zip(means, Sigmas, Ndata)])/100

# %% [markdown]
# building the model is as simple as importing the GPclust library and calling the class constructior with our data

# %%
import GPclust
m = GPclust.MOG(X, Nclust)

# %% [markdown]
# For two-dimensional data, there's a handy built-in plot function:

# %%
m.plot()

# %% [markdown]
# Here, the data are colored accorind to the (most probably) assigned cluster, and the heavy line(s) show the contours of the models probability density. Thin lines show the countours of the probablity density of each component.
#
# We can see that the model has not been fitted yet! The variational approximation to the posterior is initialized randomly, i.e. all data are randomly assigned across the clusters. To fit the approximation, call the optimize routine, and plot again.

# %%
m.optimize()
# Out:
# iteration 1 bound=771.259707163 grad=350.523256592, beta=0
# iteration 2 bound=772.028330061 grad=0.659679730111, beta=0.000428123574691
# iteration 3 bound=775.972096892 grad=1.28008487744, beta=1.76078481019
# iteration 4 bound=795.907743121 grad=5.10207741529, beta=2.05428775538
# iteration 5 bound=843.07856975 grad=21.9049258818, beta=1.70311915137
# iteration 6 bound=880.337604995 grad=33.5861814762, beta=0.759043949684
# iteration 7 bound=915.686222597 grad=27.7924511452, beta=2.07265187337
# iteration 8 bound=934.697366637 grad=53.5920143084, beta=2.22177451452
# iteration 9 bound=992.938405277 grad=175.285628213, beta=1.86831803767
# iteration 10 bound=1068.74439143 grad=140.948712596, beta=0.360919256647
# iteration 11 bound=1126.02622866 grad=60.8046535797, beta=-0.305214435736
# iteration 12 bound=1192.44118463 grad=61.7043446965, beta=0.740875420546
# iteration 14 bound=1215.29792142 grad=40.5059531445, beta=1.30195062534
# iteration 15 bound=1225.93426819 grad=14.0055208316, beta=-0.63701185827
# iteration 16 bound=1234.51753226 grad=8.65027273603, beta=-0.00548229237546
# iteration 18 bound=1244.22505158 grad=9.42193215002, beta=3.23421884121
# iteration 19 bound=1260.11583339 grad=10.9108512024, beta=0.919917973148
# iteration 20 bound=1266.85055055 grad=7.59396123876, beta=-6.01693334382
# iteration 21 bound=1279.91757635 grad=7.37721738354, beta=1.2760599077
# iteration 22 bound=1299.21101049 grad=13.8109699978, beta=1.24741377891
# iteration 24 bound=1334.16516574 grad=96.8071625695, beta=1.3585699259
# iteration 25 bound=1356.9144707 grad=38.6823303316, beta=0.404788929977
# iteration 26 bound=1364.75603752 grad=21.3836352085, beta=0.186739799074
# iteration 27 bound=1366.66873896 grad=2.50740470403, beta=0.0210982672613
# iteration 28 bound=1368.01166509 grad=1.27373605061, beta=0.175793721902
# iteration 29 bound=1369.04126991 grad=1.03342609722, beta=-0.00619083559965
# iteration 30 bound=1371.71996401 grad=1.13411017418, beta=1.41450743758
# iteration 31 bound=1375.6428297 grad=1.85671036754, beta=1.54529385481
# iteration 33 bound=1377.61765812 grad=2.30517570119, beta=1.99085711592
# iteration 34 bound=1380.65667831 grad=2.36668791359, beta=0.895435941598
# iteration 35 bound=1383.83671375 grad=2.60849822162, beta=0.763546220187
# iteration 36 bound=1386.94474784 grad=2.28557267274, beta=0.878750415511
# iteration 37 bound=1389.6836466 grad=1.42169375695, beta=2.2449987712
# iteration 38 bound=1391.36477831 grad=2.15321313362, beta=-2.00980150675
# iteration 39 bound=1392.69705365 grad=1.4062730172, beta=-0.198565075275
# iteration 40 bound=1395.34861515 grad=1.62897496293, beta=0.981286265779
# iteration 41 bound=1399.95145353 grad=2.61782410097, beta=0.906277248118
# iteration 42 bound=1409.74868308 grad=6.20648293386, beta=0.897440110725
# iteration 43 bound=1421.48738019 grad=22.0268993961, beta=0.792877300229
# iteration 44 bound=1422.48021785 grad=2.58546944103, beta=0.0376379276862
# iteration 45 bound=1423.26742853 grad=0.679106102239, beta=0.23429779238
# iteration 47 bound=1423.4750745 grad=0.351864184848, beta=79.3085023107
# iteration 48 bound=1423.5528364 grad=0.0813269332713, beta=0.178334296414
# iteration 49 bound=1423.59814523 grad=0.0360777042965, beta=0.360485230021
# iteration 50 bound=1423.62272181 grad=0.0161975591228, beta=0.485461906625
# iteration 51 bound=1423.63275256 grad=0.00654180657115, beta=0.383348124446
# iteration 52 bound=1423.63779516 grad=0.00335191671562, beta=0.379168746596
# iteration 53 bound=1423.64120579 grad=0.00204204514219, beta=0.468953936815
# iteration 54 bound=1423.64347005 grad=0.00152985116786, beta=0.286636586543
# iteration 55 bound=1423.64542481 grad=0.00143759611957, beta=0.247366328235
# iteration 56 bound=1423.64744525 grad=0.00141013821258, beta=0.319903991802
# iteration 57 bound=1423.64884479 grad=0.00140097859367, beta=-0.427216618649
# iteration 58 bound=1423.65234865 grad=0.00140219669608, beta=1.50482190212
# iteration 59 bound=1423.65899242 grad=0.00142280138148, beta=1.481841904
# iteration 60 bound=1423.66974445 grad=0.00151446550509, beta=1.35266776859
# iteration 61 bound=1423.68623659 grad=0.0017722424093, beta=1.28052350357
# iteration 62 bound=1423.71202362 grad=0.00235882596913, beta=1.26766627528
# iteration 63 bound=1423.75343242 grad=0.00355651182227, beta=1.27371005896
# iteration 64 bound=1423.81760096 grad=0.00575411960345, beta=1.2757179137
# iteration 65 bound=1423.89985763 grad=0.00910638823368, beta=1.28562113406
# iteration 66 bound=1423.91836406 grad=0.0133055763393, beta=1.67244114901
# iteration 68 bound=1423.95099201 grad=0.04652865677, beta=11.2894512164
# iteration 69 bound=1423.96493031 grad=0.0134845957375, beta=0.260557939128
# iteration 70 bound=1423.97217319 grad=0.00693520639656, beta=0.152556474742
# iteration 71 bound=1423.97830063 grad=0.0037778377878, beta=0.686864668517
# iteration 72 bound=1423.980613 grad=0.0012939918339, beta=0.430189201968
# iteration 73 bound=1423.98135071 grad=0.000422643117548, beta=0.418148801432
# iteration 74 bound=1423.98155519 grad=0.000135985222362, beta=0.284921061677
# iteration 75 bound=1423.98166833 grad=8.68847456766e-05, beta=0.245774525339
# iteration 76 bound=1423.9817888 grad=6.51933272266e-05, beta=0.680824181927
# iteration 77 bound=1423.98188726 grad=4.43142748796e-05, beta=0.633232306046
# iteration 78 bound=1423.98196045 grad=2.87264779536e-05, beta=0.646171463876
# iteration 79 bound=1423.98200848 grad=1.83517543839e-05, beta=0.577521792791
# iteration 80 bound=1423.98204076 grad=1.3056004645e-05, beta=0.539353336682
# iteration 81 bound=1423.98206645 grad=1.02776668355e-05, beta=0.601477750534
# iteration 82 bound=1423.98208925 grad=8.35965274177e-06, beta=0.68319799561
# iteration 83 bound=1423.98211042 grad=6.66521021993e-06, beta=0.771193791363
# iteration 84 bound=1423.98212873 grad=5.02792477117e-06, beta=0.773542428179
# iteration 85 bound=1423.98214337 grad=3.59385478504e-06, beta=0.761565100612
# iteration 86 bound=1423.98215428 grad=2.42268307395e-06, beta=0.750655510274
# iteration 87 bound=1423.98216161 grad=1.56316881452e-06, beta=0.698731209522
# iteration 88 bound=1423.98216644 grad=1.01539624144e-06, beta=0.696291231336
# iteration 89 bound=1423.98216967 grad=6.38958810568e-07, beta=0.729766734954
#  vb converged (gtol)

# %%
m.plot()

# %% [markdown]
# #Dirichlet process priors and the merge-split method
# Instead of using a fixed number of clusters, we can place a Dirichlet process prior over the component weights: effectively a prior of an infintie number of clusters. The variational approximation is _truncated_ se we still only model a finite number of clusters, but now we can optimize for the number of components.
#
# To help explore the search space, GPclust has a `try_split` function. This re-initialized the posterior with a cluster 'split' into two. Attempted splits are only accepted if the bound onthe marginal likelihood increases.  A wrapper around the `try_split()`, method, `systematic_splits()` repeatedly attempts splits.
#
# Let's build a MOG with a DP prior, truncated at four components:

# %%
m = GPclust.MOG(X, K=4, prior_Z='DP', alpha=10.)
m.optimize()
m.plot()
# Out:
# iteration 1 bound=912.860729287 grad=200.004799954, beta=0
# iteration 2 bound=913.101372115 grad=0.212939833693, beta=-0.000246529574942
# iteration 3 bound=914.215354898 grad=0.368896068499, beta=1.68919977179
# iteration 4 bound=920.354214182 grad=1.31776328525, beta=2.04243507262
# iteration 5 bound=943.329037743 grad=6.55201267633, beta=2.0114429112
# iteration 6 bound=972.5617407 grad=20.071383244, beta=1.2133907104
# iteration 7 bound=995.190262873 grad=20.1695976186, beta=0.867484028642
# iteration 8 bound=1001.70890682 grad=8.4912468359, beta=-0.200660156811
# iteration 9 bound=1006.5428906 grad=4.63151916102, beta=0.0994583979144
# iteration 10 bound=1029.13080627 grad=4.80581314884, beta=4.46787370434
# iteration 11 bound=1048.07129967 grad=17.8559148663, beta=2.76649881157
# iteration 12 bound=1048.23995682 grad=38.4428268686, beta=0.96578775009
# iteration 13 bound=1078.78409633 grad=34.7260021581, beta=-3.18017910866
# iteration 14 bound=1084.87989026 grad=10.166912691, beta=0.485086775989
# iteration 15 bound=1102.73704017 grad=28.5987234811, beta=-11.1890867254
# iteration 16 bound=1115.64064332 grad=16.0757091723, beta=-6.97274410087
# iteration 17 bound=1130.91227633 grad=17.2469609547, beta=0.953935422178
# iteration 18 bound=1140.05540327 grad=9.12747705106, beta=0.786756047783
# iteration 19 bound=1143.52143825 grad=4.19887958149, beta=-0.358162866245
# iteration 20 bound=1146.24217732 grad=2.5040851209, beta=0.433877305816
# iteration 21 bound=1147.42011912 grad=1.11935362523, beta=0.281892216499
# iteration 22 bound=1147.95298062 grad=0.42488033177, beta=0.38304066165
# iteration 23 bound=1148.19333858 grad=0.167472679067, beta=0.34020571833
# iteration 24 bound=1148.35525743 grad=0.0949697048715, beta=0.474638810783
# iteration 25 bound=1148.47705177 grad=0.0615719393793, beta=0.541556290306
# iteration 26 bound=1148.57189931 grad=0.0445516531828, beta=0.543400975885
# iteration 27 bound=1148.65372212 grad=0.035236977601, beta=0.599927196464
# iteration 28 bound=1148.72748633 grad=0.028888619917, beta=0.64648477865
# iteration 29 bound=1148.7933578 grad=0.0238385367164, beta=0.664697673051
# iteration 30 bound=1148.84597868 grad=0.0198491675991, beta=0.576688297812
# iteration 31 bound=1148.88985245 grad=0.0171131530495, beta=0.583261085117
# iteration 32 bound=1148.93378115 grad=0.0148209604622, beta=0.765011988239
# iteration 33 bound=1148.97637018 grad=0.0122304794714, beta=0.823353441826
# iteration 34 bound=1149.01309009 grad=0.00933423839727, beta=0.806450409311
# iteration 35 bound=1149.04053888 grad=0.00641806157913, beta=0.766890945153
# iteration 36 bound=1149.05789869 grad=0.00389188725675, beta=0.705564131052
# iteration 37 bound=1149.06732637 grad=0.00211974620838, beta=0.643837437227
# iteration 38 bound=1149.07205154 grad=0.00109010999534, beta=0.617444407096
# iteration 39 bound=1149.07432189 grad=0.000525885285479, beta=0.62158283698
# iteration 40 bound=1149.07528687 grad=0.000216464347999, beta=0.600139103083
# iteration 41 bound=1149.07560749 grad=7.0562212426e-05, beta=0.51536535373
# iteration 42 bound=1149.07569651 grad=2.21851694733e-05, beta=0.429650230644
# iteration 43 bound=1149.07572534 grad=8.25012889716e-06, beta=0.473331360705
# iteration 44 bound=1149.07573421 grad=2.76234487751e-06, beta=0.450182791644
# iteration 45 bound=1149.07573662 grad=8.95256538818e-07, beta=0.367215478589
#  vb converged (gtol)

# %% [markdown]
# With only four components, the fit is quite poor. To attempt to split the $i^\textrm{th}$ component, call `try_split(i)`. The method returns `True` if the split was sucessful, and displays the current status after each split attempt.

# %%
m.try_split(1)
# Out:
# attempting to split cluster  1
# iteration 1 bound=1131.6923634 grad=22.209536945, beta=0
# iteration 3 bound=1132.76248915 grad=1.3809410632, beta=1.26603266126
# iteration 4 bound=1133.48735243 grad=0.645534592757, beta=0.206867217676
# iteration 5 bound=1135.11913057 grad=0.699163433728, beta=5.57059234438
# iteration 7 bound=1138.02309654 grad=3.95810762963, beta=3.79686509621
# iteration 8 bound=1139.29209326 grad=1.30579444661, beta=0.286433201009
# iteration 9 bound=1140.08891538 grad=0.8305529413, beta=-0.396938984951
# iteration 10 bound=1144.07141793 grad=0.815354383297, beta=5.47210975681
# iteration 12 bound=1147.15011549 grad=3.0577616887, beta=11.3740368234
# iteration 13 bound=1156.77763527 grad=3.9779830384, beta=1.84007342578
# iteration 14 bound=1169.37980068 grad=8.44587395597, beta=1.19990417578
# iteration 16 bound=1176.29551002 grad=10.1649062008, beta=1.28003806867
# iteration 17 bound=1179.65285858 grad=3.53798744172, beta=0.293057359131
# iteration 18 bound=1181.1420736 grad=1.43423967032, beta=0.175547712833
# iteration 19 bound=1182.20695608 grad=0.934889655241, beta=0.216450233082
# iteration 21 bound=1183.0027082 grad=0.821749806762, beta=27.5800188674
# iteration 22 bound=1184.62764693 grad=0.894154403004, beta=1.05475527622
# iteration 23 bound=1187.21433604 grad=1.2003199648, beta=1.02452571846
# iteration 24 bound=1190.91507656 grad=1.90943919903, beta=0.911862935787
# iteration 25 bound=1196.63575729 grad=3.34589020941, beta=0.877002797082
# iteration 26 bound=1203.55993641 grad=6.93964068491, beta=0.822783451575
# iteration 27 bound=1209.78422087 grad=7.57938502363, beta=0.532516426651
# iteration 28 bound=1216.24633095 grad=8.54021784804, beta=0.617235219769
# iteration 29 bound=1223.00262456 grad=8.02125601174, beta=0.481913064433
# iteration 30 bound=1223.28778487 grad=1.76124820689, beta=0.110496766401
# iteration 31 bound=1223.2941889 grad=0.00742057001566, beta=0.00240184060112
# iteration 32 bound=1223.30004425 grad=0.00418029213764, beta=0.550505479881
# iteration 33 bound=1223.30351462 grad=0.00251340813744, beta=0.273621687229
# iteration 34 bound=1223.30701896 grad=0.00201189775702, beta=0.547247104371
# iteration 35 bound=1223.31046706 grad=0.0016413951871, beta=0.625666035877
# iteration 36 bound=1223.31398166 grad=0.00129049450796, beta=0.788616809394
# iteration 37 bound=1223.31696993 grad=0.000916718688749, beta=0.748117872336
# iteration 38 bound=1223.31916098 grad=0.000617287891823, beta=0.689195011206
# iteration 39 bound=1223.32074647 grad=0.000397932746158, beta=0.732670696403
# iteration 40 bound=1223.321755 grad=0.000226112987081, beta=0.699349574066
# iteration 41 bound=1223.32229817 grad=0.00011796068447, beta=0.617044008584
# iteration 42 bound=1223.32258443 grad=6.36241376015e-05, beta=0.602664069355
# iteration 43 bound=1223.32274024 grad=3.52554153183e-05, beta=0.621505604901
# iteration 44 bound=1223.32282516 grad=1.83674776796e-05, beta=0.648663112337
# iteration 45 bound=1223.3228647 grad=8.00016986471e-06, beta=0.589281538874
# iteration 46 bound=1223.32287974 grad=3.43171645343e-06, beta=0.460600691484
# iteration 47 bound=1223.32288692 grad=1.96058515211e-06, beta=0.502565259176
# iteration 48 bound=1223.32289122 grad=1.22327523125e-06, beta=0.597992570683
# iteration 49 bound=1223.32289387 grad=7.27752484327e-07, beta=0.629240122863
#  vb converged (gtol)
# split suceeded, bound changed by:  74.2471572517 , 1  new clusters (K=5)
# optimizing new split to convergence:
# iteration 1 bound=1223.32289424 grad=3.92752470014e-07, beta=0
#  vb converged (ftol)
# True

# %%
m.plot()

# %% [markdown]
# To save having to repeatedly call the try_split method, there's a helpful `systematic_splits()` fucntion, which iterates through each cluster and attempts to split it until the marginal-likelihood-bound fails to increase. Here we'll turn the out put off (it can get a bit long)

# %%
m.systematic_splits(verbose=False)

# %%
m.plot()

# %% [markdown]
# ##Getting at the parameters of the posterior.
# There are perhaps three main tasks that we'd like to do with the fitted model:
# * See which data are assigned to the same cluster
# * Examine the means (and variances) of the cluster components
# * Predict the probability density at a new point
#
# The posterior over data assignments is stored in a matix called phi. this matrix is NxK, and each element $\phi_{nk}$ represenets the probability that the $n^\textrm{th}$ datum is assigned to the $k^\textrm{th}$ component. Here we'll visualize the posterior assignment probabilities in a heatmap-style plot.

# %%
phi = m.phi
plt.matshow(phi.T, cmap=plt.cm.hot, vmin=0, vmax=1, aspect='auto')
plt.xlabel('data index')
plt.ylabel('cluster index')
plt.colorbar()
# Out:
# <matplotlib.colorbar.Colorbar instance at 0x6bdc098>

# %% [markdown]
# The variational posterior for each of the components in the MOG model is a Gaussian-Wishart distribution. these are stored in the model as so:

# %%
print 'first component mean:', m.mun[:,0]
print 'first component covariance:\n', m.Sns[:,:,0]
# Out:
# first component mean: [-0.06995597 -0.04058792]
# first component covariance:
# [[ 0.0077823   0.00327889]
#  [ 0.00327889  0.00359909]]

# %% [markdown]
# Finally, to obtain the predictive density of the model at any point, we can use`m.predict`

# %%
test_point = np.array([[0.1, 0.0]])
density = m.predict(test_point)
print density
# Out:
# [ 16.93380092]
