# %% [markdown]
# # Overlapping Mixtures of Gaussian Processses
#
# *Valentine Svensson 2015 <br> (with small edits by James Hensman November 2015)
# converted to GPflow by Daniel Marthaler September 2016*
#
# This illustrates use of the OMGP model described in
#
# **Overlapping Mixtures of Gaussian Processes for the data association problem**
# _Miguel Lázaro-Gredilla, Steven Van Vaerenbergh, Neil D. Lawrence_
# Pattern Recognition 2012
#
# The GPclust implementation makes use of the collapsed variational mixture model for GP assignment.

# %%
# %matplotlib inline
import numpy as np
import GPflow
from GPclust import OMGP
import matplotlib
matplotlib.rcParams['figure.figsize'] = (12,6)
from matplotlib import pyplot as plt

# %% [markdown]
# ## Diverging trend seperation
#
# One application of the OMGP model could be to find diverging trends among populations over time. Imagine for example two species evolving from a common ancestor over time.
#
# We load some pre-generated data which diverge over time.

# %%
XY = np.loadtxt('../data/split_data_test.csv', delimiter=',', skiprows=1, usecols=[1, 2])
X = XY[:, 0, None]
Y = XY[:, 1, None]

# %%
plt.scatter(X, Y);

# %% [markdown]
# We define a model assuming `num_clusters` = 2 trends. By default the model will be populated by `num_clusters` RBF kernels. The OMGP implementation is compatible with most kernels in GPflow, so that you for example can encode periodicity in the model.

# %%
m = OMGP(X, Y, num_clusters=2, variance=0.01, prior_Z='DP')
m.log_likelihood()
# Out:
# 1173.8270035867843

# %% [markdown]
# A simple plot function is included which illustrates the asignment probability for each data point, it also shows the posterior mean and confidence intervals for each Gaussian Process.

# %%
from plotter import OMGPplot
OMGPplot(m,X,Y)
# Out:
# plotter.py:23: RuntimeWarning: invalid value encountered in sqrt
#   plt.fill_between(XX[:, 0],YY_mu - 2.*np.sqrt(YY_var),\
# plotter.py:24: RuntimeWarning: invalid value encountered in sqrt
#   YY_mu + 2.*np.sqrt(YY_var),alpha=0.1,facecolor=col)

# %% [markdown]
# There is also a function for plotting the assignment probability for a given GP directly. Since we haven't optimized the mixture parameters yet the assignment probability is just a random draw from the prior.

# %%
from plotter import OMGPplot_probs
OMGPplot_probs(m, X, gp_num=0)

# %% [markdown]
# We can first performa a quick optimization to find the rough trends.

# %%
m.optimize(step_length=0.01)
# Out:
# iteration 1 bound=1177.96524828 grad=414.072000691, beta=0
# iteration 2 bound=1185.87082819 grad=372.514617671, beta=1.01585740684
# iteration 3 bound=1196.94069452 grad=318.273430761, beta=1.01500577685
# iteration 4 bound=1209.8519395 grad=260.064539068, beta=0.9848703327
# iteration 5 bound=1222.48200413 grad=201.32784654, beta=0.932618225116
# iteration 6 bound=1233.2517234 grad=148.060955635, beta=0.877994063101
# iteration 7 bound=1241.52970453 grad=104.516196264, beta=0.830611536127
# iteration 8 bound=1247.25495249 grad=72.2702781808, beta=0.783000330554
# iteration 9 bound=1250.85097863 grad=51.132000112, beta=0.724163842801
# iteration 10 bound=1253.07016945 grad=38.2487539457, beta=0.691947743748
# iteration 11 bound=1254.60948209 grad=29.6704644527, beta=0.75234754101
# iteration 12 bound=1255.77842831 grad=22.8682992341, beta=0.821181713673
# iteration 13 bound=1256.68169748 grad=17.2459004113, beta=0.851275697387
# iteration 14 bound=1257.36303012 grad=12.8522506075, beta=0.851907519693
# iteration 15 bound=1257.85385153 grad=9.66501845581, beta=0.83042510323
# iteration 16 bound=1258.19018432 grad=7.49820211585, beta=0.793062234924
# iteration 17 bound=1258.41582686 grad=6.08800904333, beta=0.752243909272
# iteration 18 bound=1258.57450561 grad=5.17171467738, beta=0.727952548456
# iteration 19 bound=1258.69912578 grad=4.53529845005, beta=0.735018502059
# iteration 20 bound=1258.80861589 grad=4.03601454174, beta=0.765675253906
# iteration 21 bound=1258.91159516 grad=3.59651019655, beta=0.79906477159
# iteration 22 bound=1259.01085318 grad=3.18274688856, beta=0.823441538444
# iteration 23 bound=1259.10626865 grad=2.78422985835, beta=0.837636276366
# iteration 24 bound=1259.19646466 grad=2.40195874372, beta=0.844039294388
# iteration 25 bound=1259.27976463 grad=2.04173030727, beta=0.845157986188
# iteration 26 bound=1259.35474792 grad=1.71031293987, beta=0.842893164023
# iteration 27 bound=1259.42053528 grad=1.41325840965, beta=0.838601399793
# iteration 28 bound=1259.47687418 grad=1.15381552945, beta=0.833256759934
# iteration 29 bound=1259.5240817 grad=0.932656065194, beta=0.827568777429
# iteration 30 bound=1259.56290396 grad=0.748168279005, beta=0.822052293669
# iteration 31 bound=1259.59434638 grad=0.597071366871, beta=0.817066918372
# iteration 32 bound=1259.61951645 grad=0.47512557296, beta=0.812840910885
# iteration 33 bound=1259.63950244 grad=0.377771128401, beta=0.809488691182
# iteration 34 bound=1259.65529557 grad=0.300605508112, beta=0.807027264982
# iteration 35 bound=1259.66775094 grad=0.23967740156, beta=0.805394552858
# iteration 36 bound=1259.67757769 grad=0.191621549958, beta=0.804470992781
# iteration 37 bound=1259.6853473 grad=0.153678866944, beta=0.804104107478
# iteration 38 bound=1259.69151128 grad=0.12364746145, beta=0.8041339644
# iteration 39 bound=1259.69642189 grad=0.099801220015, beta=0.804416198412
# iteration 40 bound=1259.70035204 grad=0.08080070334, beta=0.804839157808
# iteration 41 bound=1259.70351264 grad=0.0656104663177, beta=0.805332874227
# iteration 42 bound=1259.70606687 grad=0.0534291285567, beta=0.805869392201
# iteration 43 bound=1259.7081413 grad=0.0436336403866, beta=0.806455722027
# iteration 44 bound=1259.70983448 grad=0.035736576125, beta=0.807121756542
# iteration 45 bound=1259.71122347 grad=0.0293541933286, beta=0.807905832812
# iteration 46 bound=1259.7123687 grad=0.024182801134, beta=0.808840451013
# iteration 47 bound=1259.71331774 grad=0.0199812432754, beta=0.809940256776
# iteration 48 bound=1259.71410808 grad=0.0165577430571, beta=0.81119389345
# iteration 49 bound=1259.71476941 grad=0.0137598173341, beta=0.812560739572
# iteration 50 bound=1259.71532526 grad=0.0114663630836, beta=0.81397282515
# iteration 51 bound=1264.56409592 grad=0.0127655825354, beta=0.0
# iteration 52 bound=1264.56433727 grad=0.0122849923366, beta=0.983614721417
# iteration 92 bound=1264.56809692 grad=5.18785651414e-05, beta=0.963522880266
# iteration 93 bound=1264.56810315 grad=4.65271215976e-05, beta=0.971239092628
# iteration 94 bound=1264.56810818 grad=4.24288304327e-05, beta=0.98115895779
# iteration 95 bound=1264.56811206 grad=3.95036753376e-05, beta=0.993353820354
# iteration 96 bound=1264.56811482 grad=3.76944445903e-05, beta=1.00688053686
# iteration 97 bound=1264.56811641 grad=3.69769400538e-05, beta=1.02473140864
# iteration 98 bound=1264.56811672 grad=3.73738866055e-05, beta=1.04963447279
# vb converged (ftol)

# %%
OMGPplot(m,X,Y)

# %%
OMGPplot_probs(m,X)

# %% [markdown]
# The model identifies the branches of the time series, and in particular the non-branched region have ambigous GP assignment. In this region the two trends share information for prediction.
#
# Like any GPy model the hyper parameters can be inspected.

# %%
m
# Out:
# <table id='params' width=100%><tr><td>Name</td><td>values</td><td>prior</td><td>constraint</td></tr><tr><td>model.kern.item0.variance</td><td>[ 0.10735622]</td><td>None</td><td>+ve</td></tr><tr><td>model.kern.item0.lengthscales</td><td>[ 1.1884967]</td><td>None</td><td>+ve</td></tr><tr><td>model.kern.item1.lengthscales</td><td>[ 1.16954333]</td><td>None</td><td>+ve</td></tr><tr><td>model.kern.item1.variance</td><td>[ 0.0973496]</td><td>None</td><td>+ve</td></tr></table>

# %% [markdown]
# We continue by letting the model optimize some more, and also allow it to optimize the hyper parameters. The hyper parameter optimization works best if the mixture parameters have converged or are close to converging.

# %%
m.optimize(step_length=0.01, maxiter=200)
# Out:
# iteration 1 bound=1264.56876052 grad=0.00049799535637, beta=0
# iteration 2 bound=1264.56877233 grad=0.000491372249696, beta=1.41338005969
# iteration 3 bound=1264.56878993 grad=0.000475751196742, beta=1.11481486868
# iteration 4 bound=1264.56881232 grad=0.000452851782719, beta=1.04969048543
# iteration 5 bound=1264.56883838 grad=0.00042439199382, beta=1.01555871638
# iteration 6 bound=1264.56886694 grad=0.000392286004167, beta=0.992451460407
# iteration 7 bound=1264.56889686 grad=0.000358456909246, beta=0.975011766637
# iteration 8 bound=1264.56892714 grad=0.000324641976566, beta=0.961333539964
# iteration 9 bound=1264.56895698 grad=0.000292243958661, beta=0.950715876341
# iteration 10 bound=1264.56898579 grad=0.000262250041011, beta=0.942992179871
# iteration 11 bound=1264.56901319 grad=0.000235220742923, beta=0.938264269229
# iteration 12 bound=1264.56903901 grad=0.000211336597294, beta=0.936748308582
# iteration 13 bound=1264.56906323 grad=0.000190481977301, beta=0.938630561137
# iteration 14 bound=1264.56908594 grad=0.000172343572471, beta=0.943895010807
# iteration 15 bound=1264.56910728 grad=0.000156504591153, beta=0.952136335715
# iteration 16 bound=1264.56912741 grad=0.000142522435719, beta=0.962434852039
# iteration 17 bound=1264.56914646 grad=0.000129984750335, beta=0.973409778392
# iteration 18 bound=1264.56916448 grad=0.000118544367352, beta=0.983507959427
# iteration 19 bound=1264.56918148 grad=0.000107936883998, beta=0.991418214603
# iteration 20 bound=1264.56919735 grad=9.79855823646e-05, beta=0.996379606661
# iteration 21 bound=1264.56921197 grad=8.85979019525e-05, beta=0.998233761711
# iteration 22 bound=1264.56922514 grad=7.97564056913e-05, beta=0.997272409979
# iteration 23 bound=1264.56923669 grad=7.15057610185e-05, beta=0.99403555758
# iteration 24 bound=1264.56924647 grad=6.39362932056e-05, beta=0.989172124152
# iteration 25 bound=1264.56925437 grad=5.71645853193e-05, beta=0.983391462237
# iteration 26 bound=1264.56926037 grad=5.13123952711e-05, beta=0.977492524651
# iteration 27 bound=1264.56926449 grad=4.64864244954e-05, beta=0.972462021217
# iteration 28 bound=1264.56926682 grad=4.27626449674e-05, beta=0.969673065535
# iteration 29 bound=1264.5692675 grad=4.01796162135e-05, beta=0.971374329233
# vb converged (ftol)

# %%
m
# Out:
# <table id='params' width=100%><tr><td>Name</td><td>values</td><td>prior</td><td>constraint</td></tr><tr><td>model.kern.item0.variance</td><td>[ 0.10458815]</td><td>None</td><td>+ve</td></tr><tr><td>model.kern.item0.lengthscales</td><td>[ 1.18387569]</td><td>None</td><td>+ve</td></tr><tr><td>model.kern.item1.lengthscales</td><td>[ 1.17425406]</td><td>None</td><td>+ve</td></tr><tr><td>model.kern.item1.variance</td><td>[ 0.09987649]</td><td>None</td><td>+ve</td></tr></table>

# %%
OMGPplot(m,X,Y)

# %%
OMGPplot_probs(m,X)

# %% [markdown]
# ## Separating signal from noise
#
# An interesting application of the OMGP model pointed out in the original publication is the use for robust GP regression.
#
# Let's illustrate this by creating sinusoidal test data with background noise.

# %%
x1 = np.random.uniform(0, 10, (100, 1))
x2 = np.random.uniform(0, 10, (100, 1))

y1 = 4 * np.random.randn(*x1.shape)
y2 = 3 * np.sin(x2) + 0.5 * np.random.randn(*x2.shape)
x = np.vstack((x1, x2))
y = np.vstack((y1, y2))

# %%
plt.scatter(x, y);

# %% [markdown]
# First we make a model with only one mixture component / kernel. This is equivalent to normal GP regression.

# %%
kernels = [GPflow.kernels.RBF(1,lengthscales=2.0)]
m = OMGP(x, y, num_clusters=1, prior_Z='DP', kernels=kernels,variance=3.)
m.hyperparam_interval = 100

# %%
m.optimize(verbose=False)

# %%
OMGPplot(m,x,y)

# %% [markdown]
# Now we in stead view this is a mixture problem, and consider two _different_ kinds of kernels for the different GP components. One encoding white noise, and another which can encode a trend over time (an RBF kernel in this case).

# %%
kernels = [GPflow.kernels.White(1), GPflow.kernels.RBF(1, lengthscales=2.0)]
m = OMGP(x, y, num_clusters=2, prior_Z='DP', kernels=kernels, variance=3.)
m.hyperparam_interval = 250

# %%
OMGPplot(m,x,y)

# %%
m.optimize(step_length=0.01, verbose=False)

# %%
m
# Out:
# <table id='params' width=100%><tr><td>Name</td><td>values</td><td>prior</td><td>constraint</td></tr><tr><td>model.kern.item0.variance</td><td>[ 7.56375848]</td><td>None</td><td>+ve</td></tr><tr><td>model.kern.item1.variance</td><td>[ 219.46844873]</td><td>None</td><td>+ve</td></tr><tr><td>model.kern.item1.lengthscales</td><td>[ 1.79095909]</td><td>None</td><td>+ve</td></tr></table>

# %%
OMGPplot(m,x,y)

# %% [markdown]
# The trend over time is much more noticable, and the confidence intervals are smaller.
#
# Noisy points will have high assignment probability to the 'noise GP', while the assignment of the sinusoidal points is ambiguous. We can use this to seperate the points which are more likely to be noise from the remaining points.

# %%
OMGPplot_probs(m,x)
plt.axhline(0.75);

# %%
thr = 0.75
phi = m.get_phi()
idx = np.where(phi[:,0] < thr)[0]
nidx = np.where(phi[:,0] >= thr)[0]

# %%
plt.figure(figsize=(12,10))
plt.subplot(211)
plt.scatter(x[idx], y[idx]);
plt.title('Signal')

plt.subplot(212, sharey=plt.gca())
plt.scatter(x[nidx], y[nidx]);
plt.title('Noise');
